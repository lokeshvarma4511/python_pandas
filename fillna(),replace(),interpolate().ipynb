# %%
import pandas as pd

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",na_values=['not available'],nrows=10)

# %%
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no          NaN  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000          NaN          NaN     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.isna().sum().sum()
# Out:
# 7

# %%
df.notna()
# Out:
#    Date  bool   Open   High    Low  Close  Adj Close  Volume
# 0  True  True   True   True   True   True       True    True
# 1  True  True  False   True   True   True       True    True
# 2  True  True   True   True   True   True       True    True
# 3  True  True   True   True   True   True      False   False
# 4  True  True   True   True   True   True       True    True
# 5  True  True   True   True   True   True       True    True
# 6  True  True   True   True   True   True       True    True
# 7  True  True   True   True   True   True       True   False
# 8  True  True   True  False  False   True       True   False
# 9  True  True   True   True   True   True       True    True

# %%
df.fillna(5)
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no     5.000000  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000     5.000000     5.000000     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3     5.000000        5.0
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.fillna(method='pad')        #default axis=0           #'ffill'
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes           2120  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes             11  2218.399902  2178.250000     4.000000
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 3  2066.407471        2127821
# 4  2108.295410        2471703
# ...

# %%
df.fillna(method='ffill')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  2050.000000  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000  2218.399902  2178.250000     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3  2066.407471  2127821.0
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.fillna(method='bfill')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  2105.000000  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000  2220.350098  2172.000000     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3  2108.295410  2471703.0
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_15364/2343728719.py in <module>
# ----> 1 df.fillna({'Open'})
#
# D:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5174         downcast=None,
#    5175     ) -> DataFrame | None:
# -> 5176         return super().fillna(
#    5177             value=value,
#    5178             method=method,
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
# ...

# %%
df.fillna(method='bfill',axis=1,limit=2)       #limit ranges n times for a col
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no       2112.0       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0          4.0          4.0          4.0
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.fillna(method='ffill',axis=1,limit=2)
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no           no       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         11.0         11.0          4.0
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close       Volume
# 0  2032.759277    5643475.0
# 1  2074.499023    2083827.0
# 2  2066.407471    2127821.0
# 3  2132.550049  2132.550049
# 4   2108.29541    2471703.0
# 5  2102.917236    2759942.0
# ...

# %%
df.fillna(method='ffill',axis=1,limit=2,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_15364/2918756351.py in <module>
# ----> 1 df.fillna(method='ffill',axis=1,limit=2,inplace=True)
#
# D:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5174         downcast=None,
#    5175     ) -> DataFrame | None:
# -> 5176         return super().fillna(
#    5177             value=value,
#    5178             method=method,
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
# ...

# %%
df.fillna('sadf')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         sadf         sadf     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.fillna(method='ffill',axis=0,inplace=True)   #can,t implement axis=1 with inplace= true

# %%
df.fillna(method='ffill',axis=0,inplace=True,downcast='infer')

# %%
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         sadf         sadf     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %% [markdown]
# # replace()

# %%
df.replace(to_replace='yes',value='f')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20    f       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20    f       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20    f       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20    f       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20    f  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20    f       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20    f       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20    f         11.0         sadf         sadf     4.000000
# 9  17-11-20    f  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace('yes','no')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20   no       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20   no       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20   no       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20   no       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20   no  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20   no       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20   no       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20   no         11.0         sadf         sadf     4.000000
# 9  17-11-20   no  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace(2049.949951,0)
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0            0  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         sadf         sadf     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace(['yes','no'],0)
# Out:
#        Date  bool         Open         High          Low        Close  \
# 0   4-11-20     0       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20     0         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20     0       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20     0       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20     0       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20     0  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20     0       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20     0       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20     0         11.0         sadf         sadf     4.000000
# 9  17-11-20     0  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace({'bool':'yes'},'h')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20    h       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20    h       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20    h       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20    h       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20    h  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20    h       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20    h       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20    h         11.0         sadf         sadf     4.000000
# 9  17-11-20    h  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace({'bool':'yes','Adj Close':'sadf'},'h')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20    h       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20    h       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20    h       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20    h       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20    h  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20    h       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20    h       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20    h         11.0         sadf         sadf     4.000000
# 9  17-11-20    h  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3            h       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace('[A-Za-z]',0,regex=True)
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20    0       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20    0            0       2112.0  2061.300049  2102.350098
# 2   6-11-20    0       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20    0       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20    0       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20    0  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20    0       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20    0       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20    0         11.0            0            0     4.000000
# 9  17-11-20    0  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3            0          0
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         sadf         sadf     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace({'Volume':'sadf'},'nan')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         sadf         sadf     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf        nan
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace({'Volume':'[A-Za-z]'},0,regex=True)
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         sadf         sadf     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf          0
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace('sadf',method='ffill')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no       2050.0       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0  2218.399902      2178.25     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3  2066.407471  2127821.0
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace({'Volume':'sadf'},method='bfill')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no         sadf       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0         sadf         sadf     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3         sadf       sadf
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace('sadf',method='bfill',limit=2)
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no       2105.0       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0  2220.350098       2172.0     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3   2108.29541  2471703.0
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.replace('sadf',method='bfill',limit=2,inplace=True)
# Out:
# Date         None
# bool         None
# Open         None
# High         None
# Low          None
# Close        None
# Adj Close    None
# Volume       None
# dtype: object

# %%
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes       2050.0       2085.0  2049.949951  2060.050049
# 1   5-11-20   no       2105.0       2112.0  2061.300049  2102.350098
# 2   6-11-20  yes       2105.0  2123.949951       2086.0  2094.149902
# 3   9-11-20  yes       2120.0  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes       2140.0  2144.199951       2092.5  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes       2129.0       2204.0      2123.25  2192.100098
# 7  13-11-20  yes       2205.0  2218.399902      2178.25  2185.350098
# 8  14-11-20  yes         11.0  2220.350098       2172.0     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098       2172.0  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3   2108.29541  2471703.0
# 4   2108.29541  2471703.0
# 5  2102.917236  2759942.0
# ...

# %% [markdown]
# # interpolate()

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10)

# %%
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no          NaN  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951          NaN  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000          NaN          NaN     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.interpolate()
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  2077.500000  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951  2106.325074  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000  2219.375000  2175.125000     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close        Volume
# 0  2032.759277  5.643475e+06
# 1  2074.499023  2.083827e+06
# 2  2066.407471  2.127821e+06
# 3  2087.351441  2.299762e+06
# 4  2108.295410  2.471703e+06
# ...

# %%
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_15364/722817345.py in <module>
# ----> 1 df.interpolate(method='time')
#
# D:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10710         **kwargs,
#   10711     ) -> DataFrame | None:
# > 10712         return super().interpolate(
#   10713             method,
#   10714             axis,
#
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10,parse_dates=['Date'])

# %%
df
# Out:
#         Date bool         Open         High          Low        Close  \
# 0 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1 2020-05-11   no          NaN  2112.000000  2061.300049  2102.350098
# 2 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4 2020-10-11  yes  2140.000000  2144.199951          NaN  2136.600098
# 5 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8 2020-11-14  yes    11.000000          NaN          NaN     4.000000
# 9 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10,parse_dates=['Date'],index_col='Date')

# %%
df
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no          NaN  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951          NaN  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000          NaN          NaN     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close     Volume
# Date
# 2020-04-11  2032.759277  5643475.0
# 2020-05-11  2074.499023  2083827.0
# 2020-06-11  2066.407471  2127821.0
# 2020-09-11          NaN        NaN
# ...

# %%
df.interpolate(method='linear')
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no  2077.500000  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951  2106.325074  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000  2219.375000  2175.125000     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close        Volume
# Date
# 2020-04-11  2032.759277  5.643475e+06
# 2020-05-11  2074.499023  2.083827e+06
# 2020-06-11  2066.407471  2.127821e+06
# 2020-09-11  2087.351441  2.299762e+06
# ...

# %%
df.interpolate(method='time')
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no  2077.049180  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951  2106.353352  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000  2218.887451  2176.687500     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close        Volume
# Date
# 2020-04-11  2032.759277  5.643475e+06
# 2020-05-11  2074.499023  2.083827e+06
# 2020-06-11  2066.407471  2.127821e+06
# 2020-09-11  2097.995097  2.387142e+06
# ...

# %%
df.interpolate(method='index')
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no  2077.049180  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951  2106.353352  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000  2218.887451  2176.687500     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close        Volume
# Date
# 2020-04-11  2032.759277  5.643475e+06
# 2020-05-11  2074.499023  2.083827e+06
# 2020-06-11  2066.407471  2.127821e+06
# 2020-09-11  2097.995097  2.387142e+06
# ...

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10,parse_dates=['Date'],index_col='Date')

# %%
df
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no          NaN  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951          NaN  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000          NaN          NaN     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close     Volume
# Date
# 2020-04-11  2032.759277  5643475.0
# 2020-05-11  2074.499023  2083827.0
# 2020-06-11  2066.407471  2127821.0
# 2020-09-11          NaN        NaN
# ...

# %%
df.interpolate(method='index')
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no  2077.049180  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951  2106.353352  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000  2218.887451  2176.687500     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close        Volume
# Date
# 2020-04-11  2032.759277  5.643475e+06
# 2020-05-11  2074.499023  2.083827e+06
# 2020-06-11  2066.407471  2.127821e+06
# 2020-09-11  2097.995097  2.387142e+06
# ...

# %%
df
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no          NaN  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951          NaN  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000          NaN          NaN     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close     Volume
# Date
# 2020-04-11  2032.759277  5643475.0
# 2020-05-11  2074.499023  2083827.0
# 2020-06-11  2066.407471  2127821.0
# 2020-09-11          NaN        NaN
# ...

# %%
df.interpolate(method='nearest')
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no  2050.000000  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951  2108.050049  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000  2218.399902  2178.250000     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close     Volume
# Date
# 2020-04-11  2032.759277  5643475.0
# 2020-05-11  2074.499023  2083827.0
# 2020-06-11  2066.407471  2127821.0
# 2020-09-11  2108.295410  2471703.0
# ...

# %%
df
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no          NaN  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951          NaN  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000          NaN          NaN     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close     Volume
# Date
# 2020-04-11  2032.759277  5643475.0
# 2020-05-11  2074.499023  2083827.0
# 2020-06-11  2066.407471  2127821.0
# 2020-09-11          NaN        NaN
# ...

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10,parse_dates=['Date'],index_col='Date')

# %%
df.interpolate(method='polynomial',order=1)
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no  2077.049180  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951  2106.353352  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000  2218.887451  2176.687500     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close        Volume
# Date
# 2020-04-11  2032.759277  5.643475e+06
# 2020-05-11  2074.499023  2.083827e+06
# 2020-06-11  2066.407471  2.127821e+06
# 2020-09-11  2097.995097  2.387142e+06
# ...

# %%
df.interpolate(method='polynomial',order=2)
# Out:
#            bool         Open         High          Low        Close  \
# Date
# 2020-04-11  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2020-05-11   no  2145.160991  2112.000000  2061.300049  2102.350098
# 2020-06-11  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 2020-09-11  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 2020-10-11  yes  2140.000000  2144.199951  1749.122747  2136.600098
# 2020-11-11  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 2020-12-11  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 2020-11-13  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 2020-11-14  yes    11.000000  2236.666070  2193.782413     4.000000
# 2020-11-17  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#               Adj Close        Volume
# Date
# 2020-04-11  2032.759277  5.643475e+06
# 2020-05-11  2074.499023  2.083827e+06
# 2020-06-11  2066.407471  2.127821e+06
# 2020-09-11  4806.601999  2.288840e+06
# ...

# %%
df.interpolate(method='spline',order=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_15364/541979553.py in <module>
# ----> 1 df.interpolate(method='spline',order=1)
#
# D:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10710         **kwargs,
#   10711     ) -> DataFrame | None:
# > 10712         return super().interpolate(
#   10713             method,
#   10714             axis,
#
# ...
