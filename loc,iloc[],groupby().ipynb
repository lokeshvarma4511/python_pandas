# %%
import pandas as pd

# %%
s2=pd.Series([1,3,6,5,4],['ab','gh','lm','bn','mk'])
s3=s1+s2

# %%
s1
# Out:
# 1    ab
# 2    gh
# 3    hh
# 4    bn
# 5    mk
# Name: nhj, dtype: object

# %%
s1=pd.Series(['ab','gh','hh','bn','mk'],index=[1,2,3,4,5],name='nhj')
s1
# Out:
# 1    ab
# 2    gh
# 3    hh
# 4    bn
# 5    mk
# Name: nhj, dtype: object

# %%
a=['kamal','sai','nivas','shiva']
b=[90,33,58,97]
c=['p','f','p','p']
ind=['s1','s2','s3','s4']

# %%
res=pd.DataFrame({'names':a,'marks':b,'result':c},index=ind)
res
# Out:
#     names  marks result
# s1  kamal     90      p
# s2    sai     33      f
# s3  nivas     58      p
# s4  shiva     97      p

# %%
res.drop('names',axis=1)
# Out:
#     marks result
# s1     90      p
# s2     33      f
# s3     58      p
# s4     97      p

# %%
res.loc[['s1','s2']]
# Out:
#     names  marks result
# s1  kamal     90      p
# s2    sai     33      f

# %%
res.iloc[0]
# Out:
# names     kamal
# marks        90
# result        p
# Name: s1, dtype: object

# %%
res.loc['s2','names']
# Out:
# 'sai'

# %%
res.loc[['s1','s3'],['result','marks']]
# Out:
#    result  marks
# s1      p     90
# s3      p     58

# %%
res=pd.DataFrame([a,b,c],index=['y','r','s'])
res
# Out:
#        0    1      2      3
# y  kamal  sai  nivas  shiva
# r     90   33     58     97
# s      p    f      p      p

# %%
res.T
# Out:
#        y   r  s
# 0  kamal  90  p
# 1    sai  33  f
# 2  nivas  58  p
# 3  shiva  97  p

# %%
list(res.columns)
# Out:
# [0, 1, 2, 3]

# %%
res[1]
# Out:
# y    sai
# r     33
# s      f
# Name: 1, dtype: object

# %%
res=pd.DataFrame({},index=['y','r','s'])
res
# Out:
# Empty DataFrame
# Columns: []
# Index: [y, r, s]

# %%
res=pd.DataFrame({'names':a,'marks':b,'result':c},index=ind)
res
# Out:
#     names  marks result
# s1  kamal     90      p
# s2    sai     33      f
# s3  nivas     58      p
# s4  shiva     97      p

# %%
res[res['marks']>80]
# Out:
#     names  marks result
# s1  kamal     90      p
# s4  shiva     97      p

# %%
df=pd.read_csv("E:\\3rd sem\\pre ana\\mini project\\HINDUNILVR.csv")
df
# Out:
#          Date bool    Open         High          Low        Close  \
# 0     4-11-20  yes  2050.0  2085.000000  2049.949951  2060.050049
# 1     5-11-20   no     NaN  2112.000000  2061.300049  2102.350098
# 2     6-11-20  yes  2105.0  2123.949951  2086.000000  2094.149902
# 3     9-11-20  yes  2120.0  2137.649902  2108.050049  2132.550049
# 4    10-11-20  yes  2140.0  2144.199951          NaN  2136.600098
# ..        ...  ...     ...          ...          ...          ...
# 243  28-10-21  yes  2400.0  2416.000000  2368.000000  2389.649902
# 244  29-10-21  yes  2400.0  2402.000000  2373.000000  2393.149902
# 245   1-11-21  yes  2393.0  2410.899902  2368.250000  2407.100098
# 246   2-11-21  yes  2415.0  2428.000000  2402.000000  2418.899902
# 247   3-11-21  yes  2434.0  2434.000000  2386.199951  2411.350098
#
#        Adj Close     Volume
# 0    2032.759277  5643475.0
# 1    2074.499023  2083827.0
# 2    2066.407471  2127821.0
# 3            NaN        NaN
# ...

# %%
df.mean()
# Out:
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_20180/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Open         2.392444e+03
# High         2.422310e+03
# Low          2.376732e+03
# Close        2.387790e+03
# Adj Close    2.365041e+03
# Volume       1.950315e+06
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_20180/634187881.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#          Date bool         Open         High          Low        Close  \
# 0     4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1     5-11-20   no  2392.443728  2112.000000  2061.300049  2102.350098
# 2     6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3     9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4    10-11-20  yes  2140.000000  2144.199951  2376.732251  2136.600098
# ..        ...  ...          ...          ...          ...          ...
# 243  28-10-21  yes  2400.000000  2416.000000  2368.000000  2389.649902
# 244  29-10-21  yes  2400.000000  2402.000000  2373.000000  2393.149902
# ...

# %%
df.mean()
# Out:
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_20180/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Open         2.392444e+03
# High         2.422310e+03
# Low          2.376732e+03
# Close        2.387790e+03
# Adj Close    2.365041e+03
# Volume       1.950315e+06
# dtype: float64

# %%
df=pd.read_csv("E:\\3rd sem\\pre ana\\mini project\\HINDUNILVR.csv",nrows=10)
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no          NaN  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951          NaN  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000          NaN          NaN     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# ...

# %%
df.interpolate(limit=1,limit_direction='forward',limit_area='inside')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  2077.500000  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951  2106.325074  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000  2219.375000  2175.125000     4.000000
# 9  17-11-20  yes  2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close        Volume
# 0  2032.759277  5.643475e+06
# 1  2074.499023  2.083827e+06
# 2  2066.407471  2.127821e+06
# 3  2087.351441  2.299762e+06
# 4  2108.295410  2.471703e+06
# ...

# %%
df=pd.read_csv("E:\\3rd sem\\pre ana\\mini project\\HINDUNILVR.csv",nrows=9)
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no          NaN  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951          NaN  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000          NaN          NaN     4.000000
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# 6  2163.059814  3010512.0
# 7  2156.399414        NaN
# 8    45.890000        NaN

# %%
df.interpolate(limit=1,limit_direction='forward',limit_area='inside')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  2077.500000  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951  2106.325074  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000          NaN          NaN     4.000000
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3  2087.351441  2299762.0
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# 6  2163.059814  3010512.0
# 7  2156.399414        NaN
# 8    45.890000        NaN

# %%
df.interpolate(limit=1,limit_direction='forward',limit_area='outside')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no          NaN  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951          NaN  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000  2218.399902  2178.250000     4.000000
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# 6  2163.059814  3010512.0
# 7  2156.399414  3010512.0
# 8    45.890000        NaN

# %%
df.loc[df['Open']>2130]
# Out:
#        Date bool         Open         High          Low        Close  \
# 4  10-11-20  yes  2140.000000  2144.199951          NaN  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
#
#      Adj Close     Volume
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# 7  2156.399414        NaN

# %%
df.loc[0:3,'Open']
# Out:
# 0    2050.0
# 1       NaN
# 2    2105.0
# 3    2120.0
# Name: Open, dtype: float64

# %%
df.loc[0:3]
# Out:
#       Date bool    Open         High          Low        Close    Adj Close  \
# 0  4-11-20  yes  2050.0  2085.000000  2049.949951  2060.050049  2032.759277
# 1  5-11-20   no     NaN  2112.000000  2061.300049  2102.350098  2074.499023
# 2  6-11-20  yes  2105.0  2123.949951  2086.000000  2094.149902  2066.407471
# 3  9-11-20  yes  2120.0  2137.649902  2108.050049  2132.550049          NaN
#
#       Volume
# 0  5643475.0
# 1  2083827.0
# 2  2127821.0
# 3        NaN

# %%
df.iloc[0:3]
# Out:
#       Date bool    Open         High          Low        Close    Adj Close  \
# 0  4-11-20  yes  2050.0  2085.000000  2049.949951  2060.050049  2032.759277
# 1  5-11-20   no     NaN  2112.000000  2061.300049  2102.350098  2074.499023
# 2  6-11-20  yes  2105.0  2123.949951  2086.000000  2094.149902  2066.407471
#
#       Volume
# 0  5643475.0
# 1  2083827.0
# 2  2127821.0

# %%
df.iloc[:,0]
# Out:
# 0     4-11-20
# 1     5-11-20
# 2     6-11-20
# 3     9-11-20
# 4    10-11-20
# 5    11-11-20
# 6    12-11-20
# 7    13-11-20
# 8    14-11-20
# Name: Date, dtype: object

# %%
df.loc[[0]]
# Out:
#       Date bool    Open    High          Low        Close    Adj Close  \
# 0  4-11-20  yes  2050.0  2085.0  2049.949951  2060.050049  2032.759277
#
#       Volume
# 0  5643475.0

# %%
df.iloc[[True,False,True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_20180/4095193209.py in <module>
# ----> 1 df.iloc[[True,False,True]]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1551         if com.is_bool_indexer(key):
#    1552             self._validate_key(key, axis)
# -> 1553             return self._getbool_axis(key, axis=axis)
#    1554
#    1555         # a list of integers
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
# ...

# %%
df.loc[[0,2],['Open','Close']]
# Out:
#      Open        Close
# 0  2050.0  2060.050049
# 2  2105.0  2094.149902

# %%
df=pd.read_csv("E:\\3rd sem\\pre ana\\mini project\\HINDUNILVR.csv",nrows=9)

# %%
df
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no          NaN  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951          NaN  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000          NaN          NaN     4.000000
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 1  2074.499023  2083827.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# 6  2163.059814  3010512.0
# 7  2156.399414        NaN
# 8    45.890000        NaN

# %%
df.groupby('bool')

# %%
df.groupby('bool').groups
# Out:
# {'no': [1], 'yes': [0, 2, 3, 4, 5, 6, 7, 8]}

# %%
df=df.groupby(['bool','Close']).groups

# %%
df
# Out:
# {('no', 2102.350098): [1], ('yes', 4.0): [8], ('yes', 2060.050049): [0], ('yes', 2094.149902): [2], ('yes', 2131.149902): [5], ('yes', 2132.550049): [3], ('yes', 2136.600098): [4], ('yes', 2185.350098): [7], ('yes', 2192.100098): [6]}

# %%
for Section, df_1 in df:
    print(Section)
    print(df_1)
# Out:
# no
# 2102.350098
# yes
# 4.0
# yes
# 2060.050049
# yes
# 2094.149902
# yes
# 2131.149902
# yes
# 2132.550049
# yes
# 2136.600098
# yes
# 2185.350098
# yes
# 2192.100098

# %%
list(df)
# Out:
# [('no', 2102.350098),
#  ('yes', 4.0),
#  ('yes', 2060.050049),
#  ('yes', 2094.149902),
#  ('yes', 2131.149902),
#  ('yes', 2132.550049),
#  ('yes', 2136.600098),
#  ('yes', 2185.350098),
#  ('yes', 2192.100098)]

# %%
dict(list(df))
# Out:
# {'no': 2102.350098, 'yes': 2192.100098}

# %%
df.groupby('bool').get_group('no')
# Out:
#       Date bool  Open    High          Low        Close    Adj Close  \
# 1  5-11-20   no   NaN  2112.0  2061.300049  2102.350098  2074.499023
#
#       Volume
# 1  2083827.0

# %%
df.groupby('bool').get_group('yes')
# Out:
#        Date bool         Open         High          Low        Close  \
# 0   4-11-20  yes  2050.000000  2085.000000  2049.949951  2060.050049
# 2   6-11-20  yes  2105.000000  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes  2120.000000  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes  2140.000000  2144.199951          NaN  2136.600098
# 5  11-11-20  yes  2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes  2129.000000  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes  2205.000000  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes    11.000000          NaN          NaN     4.000000
#
#      Adj Close     Volume
# 0  2032.759277  5643475.0
# 2  2066.407471  2127821.0
# 3          NaN        NaN
# 4  2108.295410  2471703.0
# 5  2102.917236  2759942.0
# 6  2163.059814  3010512.0
# 7  2156.399414        NaN
# 8    45.890000        NaN

# %%
df1=df.groupby('bool').get_group('yes')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_404/4056128422.py in <module>
# ----> 1 df1=df.groupby('Open').get_group('yes')
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     752         inds = self._get_index(name)
#     753         if not len(inds):
# --> 754             raise KeyError(name)
#     755
#     756         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: 'yes'

# %%
df1.sum()
# Out:
# Date         4-11-206-11-209-11-2010-11-2011-11-2012-11-201...
# bool                                  yesyesyesyesyesyesyesyes
# Open                                              14896.600098
# High                                              15051.799804
# Low                                               12650.100098
# Close                                             14935.950196
# Adj Close                                         12675.728622
# Volume                                              16013453.0
# dtype: object

# %%
df1.mean()
# Out:
# C:\Users\LOKEVA~1\AppData\Local\Temp/ipykernel_404/2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# Open         1.862075e+03
# High         2.150257e+03
# Low          2.108350e+03
# Close        1.866994e+03
# Adj Close    1.810818e+03
# Volume       3.202691e+06
# dtype: float64
