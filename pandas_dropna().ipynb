# %%
import pandas as pd

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10)

# %%
df.dropna()     #defaultly sets to axis=0,how='any',
#drops every row contains nan,null.. values
#df.dropna(axis=0,1,how='any','all',thresh=0-n-1,subset=['column name'],inplace)
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 4  2108.295410        2471703
# 5  2102.917236        2759942
# 6  2163.059814        3010512
# 7  2156.399414  not available
# 9  2148.751953        2733542

# %%
df.dropna(axis=1)
#drops every column contains nan values
# Out:
#        Date bool           Open        Close
# 0   4-11-20  yes           2050  2060.050049
# 1   5-11-20   no  not available  2102.350098
# 2   6-11-20  yes           2105  2094.149902
# 3   9-11-20  yes           2120  2132.550049
# 4  10-11-20  yes           2140  2136.600098
# 5  11-11-20  yes    2136.600098  2131.149902
# 6  12-11-20  yes           2129  2192.100098
# 7  13-11-20  yes           2205  2185.350098
# 8  14-11-20  yes             11     4.000000
# 9  17-11-20  yes    2220.350098  2177.600098

# %%
df.dropna(axis=0)
#drops every row contains nan values
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 4  2108.295410        2471703
# 5  2102.917236        2759942
# 6  2163.059814        3010512
# 7  2156.399414  not available
# 9  2148.751953        2733542

# %%
df.dropna(how='any')#drops specified row/column. if atleast one element is nan. defaultly set axis=0
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277             no
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 4  2108.295410        2471703
# 5  2102.917236        2759942
# 6  2163.059814        3010512
# 7  2156.399414  not available
# 9  2148.751953        2733542

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10)
df
# Out:
#        Date bool           Open         High  Low        Close    Adj Close  \
# 0   4-11-20  yes           2050  2085.000000  NaN  2060.050049  2032.759277
# 1   5-11-20   no  not available  2112.000000  NaN  2102.350098  2074.499023
# 2   6-11-20  yes           2105  2123.949951  NaN  2094.149902  2066.407471
# 3   9-11-20  yes           2120  2137.649902  NaN  2132.550049          NaN
# 4  10-11-20  yes           2140  2144.199951  NaN  2136.600098  2108.295410
# 5  11-11-20  yes    2136.600098  2138.600098  NaN  2131.149902  2102.917236
# 6  12-11-20  yes           2129  2204.000000  NaN  2192.100098  2163.059814
# 7  13-11-20  yes           2205  2218.399902  NaN  2185.350098  2156.399414
# 8       NaN  NaN            NaN          NaN  NaN          NaN          NaN
# 9  17-11-20  yes    2220.350098  2220.350098  NaN  2177.600098  2148.751953
#
#           Volume
# 0             no
# 1        2083827
# 2        2127821
# 3        2194404
# 4        2471703
# 5        2759942
# ...

# %%
df.dropna(how='all')  #drops rows containing every element null
# Out:
#        Date bool           Open         High  Low        Close    Adj Close  \
# 0   4-11-20  yes           2050  2085.000000  NaN  2060.050049  2032.759277
# 1   5-11-20   no  not available  2112.000000  NaN  2102.350098  2074.499023
# 2   6-11-20  yes           2105  2123.949951  NaN  2094.149902  2066.407471
# 3   9-11-20  yes           2120  2137.649902  NaN  2132.550049          NaN
# 4  10-11-20  yes           2140  2144.199951  NaN  2136.600098  2108.295410
# 5  11-11-20  yes    2136.600098  2138.600098  NaN  2131.149902  2102.917236
# 6  12-11-20  yes           2129  2204.000000  NaN  2192.100098  2163.059814
# 7  13-11-20  yes           2205  2218.399902  NaN  2185.350098  2156.399414
# 9  17-11-20  yes    2220.350098  2220.350098  NaN  2177.600098  2148.751953
#
#           Volume
# 0             no
# 1        2083827
# 2        2127821
# 3        2194404
# 4        2471703
# 5        2759942
# 6        3010512
# 7  not available
# 9        2733542

# %%
df.dropna(axis=1,how='all')  #drops column containing every element null
# Out:
#        Date bool           Open         High        Close    Adj Close  \
# 0   4-11-20  yes           2050  2085.000000  2060.050049  2032.759277
# 1   5-11-20   no  not available  2112.000000  2102.350098  2074.499023
# 2   6-11-20  yes           2105  2123.949951  2094.149902  2066.407471
# 3   9-11-20  yes           2120  2137.649902  2132.550049          NaN
# 4  10-11-20  yes           2140  2144.199951  2136.600098  2108.295410
# 5  11-11-20  yes    2136.600098  2138.600098  2131.149902  2102.917236
# 6  12-11-20  yes           2129  2204.000000  2192.100098  2163.059814
# 7  13-11-20  yes           2205  2218.399902  2185.350098  2156.399414
# 8       NaN  NaN            NaN          NaN          NaN          NaN
# 9  17-11-20  yes    2220.350098  2220.350098  2177.600098  2148.751953
#
#           Volume
# 0             no
# 1        2083827
# 2        2127821
# 3        2194404
# 4        2471703
# 5        2759942
# 6        3010512
# 7  not available
# 8            NaN
# ...

# %%
#thresh=x   #prints the rows/columns which has atleast specified number of notnull values

# %%
df.dropna(thresh=7)        #default axis=0
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 4  2108.295410        2471703
# 5  2102.917236        2759942
# 6  2163.059814        3010512
# 7  2156.399414  not available
# 9  2148.751953        2733542

# %%
df.dropna(axis=1,thresh=9)    #drops columns contains atlest specified notnull values
# Out:
#        Date bool           Open         High        Close         Volume
# 0   4-11-20  yes           2050  2085.000000  2060.050049             no
# 1   5-11-20   no  not available  2112.000000  2102.350098        2083827
# 2   6-11-20  yes           2105  2123.949951  2094.149902        2127821
# 3   9-11-20  yes           2120  2137.649902  2132.550049        2194404
# 4  10-11-20  yes           2140  2144.199951  2136.600098        2471703
# 5  11-11-20  yes    2136.600098  2138.600098  2131.149902        2759942
# 6  12-11-20  yes           2129  2204.000000  2192.100098        3010512
# 7  13-11-20  yes           2205  2218.399902  2185.350098  not available
# 8       NaN  NaN            NaN          NaN          NaN            NaN
# 9  17-11-20  yes    2220.350098  2220.350098  2177.600098        2733542

# %%
#if we want to check only individual column wise use      subset=['']

# %%
df=pd.read_csv("E:\\3rd sem\pre ana\\mini project\\HINDUNILVR.csv",nrows=10)
df
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes           2120  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes             11          NaN          NaN     4.000000
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 3          NaN            NaN
# 4  2108.295410        2471703
# ...

# %%
df.dropna(subset=['High'])
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 3   9-11-20  yes           2120  2137.649902  2108.050049  2132.550049
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 3          NaN            NaN
# 4  2108.295410        2471703
# 5  2102.917236        2759942
# 6  2163.059814        3010512
# ...

# %%
df.dropna(subset=['Adj Close'])
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 8  14-11-20  yes             11          NaN          NaN     4.000000
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 4  2108.295410        2471703
# 5  2102.917236        2759942
# 6  2163.059814        3010512
# 7  2156.399414  not available
# ...

# %%
#inplace=True is used to directly reflect the changes to dataframe

# %%
df.dropna(inplace=True)
df
# Out:
#        Date bool           Open         High          Low        Close  \
# 0   4-11-20  yes           2050  2085.000000  2049.949951  2060.050049
# 1   5-11-20   no  not available  2112.000000  2061.300049  2102.350098
# 2   6-11-20  yes           2105  2123.949951  2086.000000  2094.149902
# 4  10-11-20  yes           2140  2144.199951  2092.500000  2136.600098
# 5  11-11-20  yes    2136.600098  2138.600098  2104.600098  2131.149902
# 6  12-11-20  yes           2129  2204.000000  2123.250000  2192.100098
# 7  13-11-20  yes           2205  2218.399902  2178.250000  2185.350098
# 9  17-11-20  yes    2220.350098  2220.350098  2172.000000  2177.600098
#
#      Adj Close         Volume
# 0  2032.759277        5643475
# 1  2074.499023        2083827
# 2  2066.407471        2127821
# 4  2108.295410        2471703
# 5  2102.917236        2759942
# 6  2163.059814        3010512
# 7  2156.399414  not available
# 9  2148.751953        2733542
